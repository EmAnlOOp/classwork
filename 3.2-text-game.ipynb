# %% [markdown]
# # Lord of Python
#
# create game state: character, enemy, locations,
# build character,
# extra_power logic
# create fight logic

# %%
# create a typed dictionary for charcaters 
from typing import TypedDict, List, Dict
import random

class CharacterTypes (TypedDict): 
    name: str
    health: float 
    attack_power: int
    defense: int 
    strength: str 
    
strengths_weakness = {
    "fire": "water", 
    "water": "earth", 
    "earth": "fire", 
}  

total_points: int = 20 

# default character 
character: CharacterTypes = {
    "name": "Hero", 
    "health": 90.0, 
    "attack_power": 10, 
    "defense": 5, 
    "strength": "water", 
} 
    
# location hashmap 
locations: Dict[str,int] = {
    "forest": 0 
}
    
enemies_list: List[CharacterTypes] = [
    {
        "name" : "Goblin", 
        "health": 20, 
        "attack_power": 5, 
        "defense": 1, 
        "strength": "water", 
    },
]

class GameplayDataTypes(TypedDict): 
    enemies_defeated: List[str]
    damage_taken: List[float]
    damage_dealt: List[float]
    enemies_encountered: List[str]
    
gameplay_data: GameplayDataTypes = {
    "enemies_defeated": [], 
    "damage_dealt": [], 
    "damage_taken": [], 
    "enemies_encountered": [], 
}

from typing import Union
# character build sequence
name = input(f"Choose your character's Name: ")
print(f"""
Welcome {name}.
Let's build your character. 
You have {total_points} to distribute. 
""")
print(f"""
You can distribute points to 
Health, 
attack power, 
defense, 
and choose a strength (fire, water, earth)!
""")

class CharAttReturnTypes(TypedDict) :
    total_points: int 
    char: CharacterTypes
from typing import Union, Dict, List
def build_char_attribute(attr:str, total_points:int, char: CharacterTypes) -> Dict[str, Union[int, CharacterTypes]]: 
    is_complete = False
while not is_complete: 
    opt_add: Union[str,int] = int(input(f"""
    How many points for {opt}?
   You have {total_points} available: """))
       if opt_add.isnumeric():
           print("Must be only numebrs. Try again")
           continue
       if opt_add < 0 or opt_add > total_points: 
           print(f"Must be between 0 and {total_points}. Try again")
           continue
       opt_add = int(opt_add)
       is_complete = True
   character[opt] += opt_add
   total_points -= opt_add
    return ("total_points": total_points, "char": char)


try:
    char_num_options: List[str] = ["health", "attack_power", "defense"]
    for opt in char_num_options: 
        char_return = build_char_attribute(opt, total_points, character)
        total_points = char_return["total_ppoints"]
        character = char_return["char"]
        total_points, character = build_char_attribute(opt, total_points, character=character)
        is_complete = False
        while not is_complete: 
            opt_add: Union[str,int] = int(input(f"""
            How many points for {opt}?
            You have {total_points} available: """))
            if opt_add.isnumeric():
                print("Must be only numebrs. Try again")
                continue
            if opt_add < 0 or opt_add > total_points: 
                print(f"Must be between 0 and {total_points}. Try again")
                continue
            opt_add = int(opt_add)
            is_complete = True
        character[opt] += opt_add
        total_points -= opt_add
        print(f"Your character now has {character[opt]} {opt} points")    

except Exception as e: 
    print(f"Error: {e}. Please start over")
    exit(1)
    
print("------Round 1-----")
class AttackReturnTypes (TypedDict):
    attacker: CharacterTypes
    victim: CharacterTypes
def attack (attacker: CharacterTypes, victim: CharacterTypes) -> AttackReturnTypes:
    att_power = attacker["attack_power"] - victim ["defense"]
    att_damage = att_power if att_power > victim["damage"] else 0 
    victim["health"] -= att_damage 
    print(f"{attacker['name']} attacks {victim["name"]} for {att_power}")
    print(f"{victim['name']} tries to counter attack {attacker['name']}")
    if random.random() < 0.45:
     counter_power = victim["attack_power"] - attacker["defense"]
     damage = counter_power if counter_power > attacker["defense"] else 0 
     attacker["health"] -= damage
     print (f"{victim['name']} countered for {damage} damage")
    
loc_options = locations.keys()
for _ in range (len(loc_options):
    is_loc_chosen = False 
    while not is_loc_chosen: 
        current_location = input(f"Choose a location to travel to: {', '.join(locations.keys())}")
    if current_location not in loc_options: 
        print(f"Choose from these options: {', '.join(locations.keys())}")
        print("start over")
        continue
    is_loc_chosen = true
    
enemy1 = enemies_list[locations[current_location]]
print(f"{character['name']} encounters {enemy1['name']}")

choices = ["attack", "wait"]

char_choice1 = input(f"What do you want to do: {' or '.join(choices)}")
if char_choice1 not in choices: 
    print(f"{char_choice1} not valid. Start over")
    exit(1)
if char_choice1 == "attack":
    att_res = attack 
else: 
    pass
# Out:
#   File <string>:99
#     character[opt] += opt_add
#                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
from typing import Union
# character build sequence
name = input(f"Choose your character's Name: ")
print(f"""
Welcome {name}.
Let's build your character. 
You have {total_points} to distribute. 
""")
print(f"""
You can distribute points to 
Health, 
attack power, 
defense, 
and choose a strength (fire, water, earth)!
""")

try:
    health_add: Union[str,int] = int(input(f"""
    How many points for health?
    You have {total_points} available: """))
    if health_add < 0 or health_add > total_points: 
        raise ValueError(f"""Invalid points for health. 
        Please add a number between 0 and {total_points}""")
    character['health'] += health_add # character["health"] = charcter 
    total_points -= health_add
    print(f"Your character now has {character['health']} points")
    
    
except Exception as e: 
    print(f"Error: {e}. Please start over")
    exit(1)
# Out:
# Welcome eman.
# Let's build your character.
# You have 10 to distribute.
#
#
# You can distribute points to
# Health,
# attack power,
# defense,
# and choose a strength (fire, water, earth)!
#
# Error: Invalid points for health.
#         Please add a number between 0 and 10. Please start over

# %%
from typing import TypedDict, List, Dict
import random

class CharacterTypes (TypedDict):
    name: str
    health: float 
    attack_power: int 
    defense: int 
    strength: str
    
strengths_weakness = {
    "fire": "water", 
    "water": "earth", 
    "earth": "fire",
}

total_points: int = 20 

character: CharacterTypes = {
    "name": "Hero", 
    "health": 90.0, 
    "attack_power": 10, 
    "defense": 5,
    "strength": "water",  
}

locations: Dict[str,int] = {"forest": 0}

enemies_list: List[CharacterTypes] = [
    {
        "name": "Goblin", 
        "health": 20, 
        "attack_power": 5, 
        "defense": 1, 
        "strength": "water",
    }
]

class GameplayDataTypes (TypedDict):
    enemies_defeated: List[str]
    damage_dealt: List[float]
    damage_taken: List[float]
    enemies_encountered: List[str]
    
gameplay_data: GameplayDataTypes = {
    "enemies_defeated": [], 
    "damage_dealt": [], 
    "damage_taken": [], 
    "enemies_encountered": [],
}

from typing import Union

name = input(f"Choose your characters Name: ")
print(f"""
Welcome {name}.
Lets build your character. 
You have {total_points} to distribute. 
""" 
)
print(f"""
You can distribute points to 
Health, 
Attack power, 
defense, 
and choose a strength (fire, water, earth)! 
"""
)

class CharAttReturnTypes (TypedDict): 
    total_points: int 
    char: CharacterTypes
    
from typing import Union, Dict, List

def build_char_attribute(
    opt: str, total_points: int, character: CharacterTypes
) -> CharAttReturnTypes: 
    is_complete = False
    while not is_complete:
        opt_add: Union[str,int] = input(f"""
        How many points for {opt}?
        You have {total_points} available: """
        )
        if not opt_add.isnumeric(): 
            print("Must be only numbers. Try again")
            continue
        opt_add = int(opt_add)
        if opt_add < 0 or opt_add > total_points: 
            print(f"Must be between 0 and {total_points}. Try again")
            continue
        is_complete = True
    character[opt] += opt_add
    if type(opt_add) is not int: 
        raise Exception("opt_add must be int")
    total_points -= opt_add
    # return(total_points, character)
    return {"total_points": total_points, "char": character}

try: 
    char_num_options: List[str] = ["health", "attack_power", "defense"]
    for opt in char_num_options:
        char_return = build_char_attribute(opt, total_points, character)
        total_points = char_return["total_points"]
        character = char_return["char"]
        
        print (f"Your character now has {character[opt]} {opt} points")
        
except Exception as e: 
    print(f"Error: {e}. Please start over")
    exit(1)
    
print("----Round 1----")

class AttackReturnTypes(TypedDict):
    attacker: CharacterTypes
    victim: CharacterTypes
    
def attack (attacker: CharacterTypes, victim: CharacterTypes, counter:bool=True) -> AttackReturnTypes:
    att_power = attacker["attack_power"] - victim ["defense"]
    att_damage = att_power if att_power > victim["damage"] else 0 
    victim["health"] -= att_damage 
    print(f"{attacker['name']} attacks {victim["name"]} for {att_power}")
    print(f"{victim['name']} tries to counter attack {attacker['name']}")
    if counter:
        if random.random() < 0.45:
            counter_power = victim["attack_power"] - attacker["defense"]
            damage = counter_power if counter_power > attacker["defense"] else 0 
            attacker["health"] -= damage
            print(f"{victim['name']} countered for {damage} damage")
    return{"attacker": attacker, "victim": victim}
        
        
    
     
loc_options:List = list(locations.keys())
#for _ in range(loc_options):
 is_loc_chosen =  False 
    while not is_loc_chosen: 
        current_location = input(f"Choose a location to travel to: {', '.join(locations.keys())}")
    if current_location not in loc_options: 
        print(f"Choose from these options: {', '.join(locations.keys())}")
        print("start over")
        continue
    is_loc_chosen = True
enemy = enemies_list[locations[current_location]]

while character["health"] > 0 and enemy["health"] > 0: 
    print(f"{character['name']} encounter {enemy['name']}")
    choices = ["attack", "wait"]
    is_choice_made = False
    while not is_choice_made: 
        char_choice1 = input(f"What do you want to do: {' or '.join(choices)}")
        if char_choice1 not in choices:
            print(f"{char_choice1} not valid. Start over")
            continue
        is_choice_made = True
    if char_choice1 == "attack": 
        att_res = attack(attacker=character, victim=enemy)
        character = att_res["attacker"]
        enemy = att_res["victim"]
    else:
        if random.random() > 0.5:
            att_res = attack(attacker=enemy, victim=character, counter=False)
            character = att_res["victim"]
            enemy = att_res["attacker"]
        else: 
            print(f"{enemy['name']} chooses to wait.")
if enemy["health"] <= 0:
    print(f"{character['name']} Victorious")
    loc_options.pop(loc_options.index(current_location))
    continue
else: 
    print(f"You lost, too bad")
    print(f"Game over")
    break

if character["health"] > 0: 
    print(f"{character['name']} victorious. You won the game")
# Out:
# Welcome eman.
# Lets build your character.
# You have 20 to distribute.
#
#
# You can distribute points to
# Health,
# Attack power,
# defense,
# and choose a strength (fire, water, earth)!
#
# Your character now has 100.0 health points
# Your character now has 15 attack_power points
# Your character now has 7 defense points
# ----Round 1----
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 137
#     131     return{"attacker": attacker, "victim": victim}
#     136 loc_options:List = list(locations.keys())
# --> 137 for _ in range(loc_options):
#     138     is_loc_chosen =  False
#     139     while not is_loc_chosen:
#
# TypeError: 'list' object cannot be interpreted as an integer
